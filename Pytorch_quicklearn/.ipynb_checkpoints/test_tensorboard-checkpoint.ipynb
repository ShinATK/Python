# %% [markdown]
# 在cmd中输入：`tensorboard --logdir=logs`
#
# ![image.png](attachment:d87b5379-69b2-43e0-b6ee-affd7098569e.png)
#
# 只改变scalar而不改变title：↓
#
# ![image.png](attachment:22188ce4-52e1-4e61-9484-85a4791a5663.png)
#
# 最后会导致在tensorboard中更新在同一个图片中
#
# ![image.png](attachment:66790c3a-a92f-4457-b67c-ab39757be1cc.png)

# %%
# %load test_tb.py
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter("logs")

# writer.add_image()

# y=2x
for i in range(100):
    writer.add_scalar("y=2x", 3*i, i)

writer.close()

# %%
from PIL import Image
image_path = "data\\train\\ants_image\\0013035.jpg"
img = Image.open(image_path)
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np
img_array = np.array(img)
type(img_array)
# Out:
# numpy.ndarray

# %%
img_array.shape
# Out:
# (512, 768, 3)
